# %%
import cv2
import numpy as np

# %%
img = cv2.imread("membrane.jpg", 0)
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[9], line 2
#       1 img = cv2.imread("membrane.jpg", 0)
# ----> 2 img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#
# error: OpenCV(4.13.0) C:\Users\task_177929050858369\croot\opencv-suite_1779290580920\work\modules\imgproc\src\color.simd_helpers.hpp:92: error: (-15:Bad number of channels) in function '__cdecl cv::impl::`anonymous-namespace'::CvtHelper<struct cv::impl::`anonymous namespace'::Set<3,4,-1>,struct cv::impl::A0xeb476a63::Set<1,-1,-1>,struct cv::impl::A0xeb476a63::Set<0,2,5>,4>::CvtHelper(const class cv::_InputArray &,const class cv::_OutputArray &,int)'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1

# %%
cv2.imshow("membrane", img)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
